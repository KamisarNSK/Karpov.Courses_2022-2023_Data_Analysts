# %% [markdown]
# # 1 УРОК МЕТОДИКИ ОПРЕДЕЛЕНИЯ ПОТРЕБНОСТЕЙ ПОЛЬЗОВАТЕЛЯ: ОСНОВНЫЕ ФРЕЙМВОРКИ

# %% [markdown]
# # Шаг 1

# %% [markdown]
# #### “Как Саша, я хочу организовать своё собственное расписание, чтобы успевать больше”. Эта формулировка соответствует методу:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Шаг 2

# %% [markdown]
# #### “Когда я хожу в спортзал, я хочу носить красивую спортивную форму, чтобы мне делали комплименты”. Эта формулировка соответствует:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Шаг 3

# %% [markdown]
# #### Карта эмпатии помогает:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Шаг 4

# %% [markdown]
# #### Напишите 3 JTBD для сервиса по доставке продуктов «Самокат»

# %% [markdown]
# #### !Чужое -->
# - Когда у меня нет возможности пойти в магазин, я хочу заказать доставку еды, чтобы это было быстро и до двери, так я могу потратить свое время на личные дела вместо похода в магазин.
# - Когда я захожу в приложение по доставке еды, я хочу, чтобы интерфейс был интуитивно понятен и я быстро смог найти и заказать необходимые продукты, так я останусь доволен и не захочу перейти к другому сервису, в котором все удобно и понятно.
# - Когда я делаю заказ продуктов, я хочу, чтобы все необходимое было доставлено без ошибок и вовремя, так я не буду тратить свое время на разрешение неприятной ситуации.

# %% [markdown]
# - Когда мне будет **совсем лень** подняться с дивана, то я потрачу время чтоб установить приложение "самокат", чтоб кто то сходил в магазин вместо меня и что-то когда-то принес мне..
#
#
# - Когда мне будет **совсем лень** подняться с дивана, и у меня уже установлено приложение "самокат"... было б не плохо чтоб выбранные продукты моментально появились у меня на столе) и чтоб курьер по пути от меня еще вынес мусор(от прошлой доставки)
#
#
# - Летом на даче, чтоб не ехать с утра в деревню в магазин за настоящим молоком, сметаной  и свежим хлебом, вызову ка я "самокат" ? пусть что-нибудь привезет из города(60 км) свеженького? и вкусненнького) а по пути пусть еще захватит воды из колодца.. ну и естественно вывезет мусор) ну и конечно бесплатно))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Шаг 5

# %% [markdown]
# #### ⭐️Задание со звёздочкой!⭐️
#
# Заполните Value Proposition Canvas для своего любимого продукта.
#
# Формат ответа: jpeg (картинка) с заполненным шаблоном value proposition canvas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
