# %% [markdown]
# # 2 УРОК ОСНОВЫ УПРАВЛЕНИЯ ПРОДУКТОМ

# %% [markdown]
# ## Задание
# Ваш продукт – приложение для доставки еды "Самокат". Проанализируйте его по модели Business Model Canvas в Miro. Оцениваться будет полнота и глубина анализа.
#
# Формат сдачи
# Шаблон Business Model Canvas, заполненный в Miro (JPEG файл 16:9).

# %% [markdown]
# ![Business%20Model%20Canvas.jpg](attachment:Business%20Model%20Canvas.jpg)

# %% [markdown]
# ![Business%20Model%20Canvas%20%D0%A1%D0%90%D0%9C%D0%9E%D0%9A%D0%90%D0%A2.jpg](attachment:Business%20Model%20Canvas%20%D0%A1%D0%90%D0%9C%D0%9E%D0%9A%D0%90%D0%A2.jpg)
